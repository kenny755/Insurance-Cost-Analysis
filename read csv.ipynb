# %%
import pandas as pd
path = "C:\\Users\\Hp\\OneDrive\\Desktop\\PYTHON FOLDER\\Cleaned Data Stock Analyst Dataset.csv"
df = pd.read_csv(path, header=None, low_memory=False)
print(df)
df.info()
df.describe(include='all')
# Out:
#                  0             1                   2  \
# 0       WORK_GROUP  SHIPPED DATE  Product Code / SKU
# 1           ONLINE    22/09/2024           211165706
# 2           ONLINE    22/09/2024           211165877
# 3           ONLINE    22/09/2024           211180580
# 4           ONLINE    22/09/2024           211158977
# ...            ...           ...                 ...
# 115213      ONLINE    19/10/2024           211143839
# 115214      ONLINE    19/10/2024           211250169
# 115215      ONLINE    19/10/2024           211250159
# 115216      ONLINE    19/10/2024           211250164
# 115217      ONLINE    19/10/2024           211290565
#
#                                               3             4              5  \
# 0                           Product_DESCRIPTION  ORDER_NUMBER  Units Ordered
# 1            SATIN KHAKI LACE LEG:Khaki:M-12/14  GB1507460823              1
# 2           SATIN KHAKI LACE CAMI:Khaki:M-12/14  GB1507460823              1
# ...

# %%
import pandas as pd
import numpy as np
path = "C:\\Users\\Hp\\OneDrive\\Desktop\\PYTHON FOLDER\\Cleaned Data Stock Analyst Dataset.csv"
df = pd.read_csv(path, header=None, low_memory=False)
print(df)
df.describe()
# Out:
#                  0             1                   2  \
# 0       WORK_GROUP  SHIPPED DATE  Product Code / SKU
# 1           ONLINE    22/09/2024           211165706
# 2           ONLINE    22/09/2024           211165877
# 3           ONLINE    22/09/2024           211180580
# 4           ONLINE    22/09/2024           211158977
# ...            ...           ...                 ...
# 115213      ONLINE    19/10/2024           211143839
# 115214      ONLINE    19/10/2024           211250169
# 115215      ONLINE    19/10/2024           211250159
# 115216      ONLINE    19/10/2024           211250164
# 115217      ONLINE    19/10/2024           211290565
#
#                                               3             4              5  \
# 0                           Product_DESCRIPTION  ORDER_NUMBER  Units Ordered
# 1            SATIN KHAKI LACE LEG:Khaki:M-12/14  GB1507460823              1
# 2           SATIN KHAKI LACE CAMI:Khaki:M-12/14  GB1507460823              1
# ...
